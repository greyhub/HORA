# %%
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import xgboost as xgb

# %%
rank = pd.read_csv("./Demo_4k/rank.csv")
rank = rank[-rank['latitude'].isna()]

# %%
def get_ensemble_models():
    rf = RandomForestRegressor(n_estimators=51,min_samples_leaf=5,min_samples_split=3)
    bagg = BaggingRegressor(n_estimators=51,random_state=42)
    extra = ExtraTreesRegressor(n_estimators=51,random_state=42)
    ada = AdaBoostRegressor(n_estimators=51,random_state=42)
    grad = GradientBoostingRegressor(n_estimators=51,random_state=42)
    regressor_list = [rf,bagg,extra,ada,grad]
    regressor_name_list = ['Random Forests','Bagging','Extra Trees','AdaBoost','Gradient Boost']
    return regressor_list,regressor_name_list
    
def print_evaluation_metrics(trained_model,trained_model_name,X_test,y_test):
    print('--------- Model : ', trained_model_name, ' ---------------\n')
    predicted_values = trained_model.predict(X_test)
    print(metrics.mean_absolute_error(y_test,predicted_values))
    print('Mean Absolute Error (MAE):', metrics.mean_absolute_error(y_test,predicted_values))
    print('Mean Squared Error (MSE):', metrics.mean_squared_error(y_test,predicted_values))
    print('Root Mean Squared Error (RMSE):', np.sqrt(metrics.mean_squared_error(y_test,predicted_values)))
    print('R2_score:', metrics.r2_score(y_test,predicted_values))
    print("---------------------------------------\n")

# %% [markdown]
# # Fill Missing Value of counts_search

# %%
search = rank[['hotel_id', 'score_mean','counts_search','review_score','tours','relax_spa','currency_exchange',
 'safely_deposit_boxed', 'luggage_storage', 'restaurants', 'concierge',
 'front_desk_24_hour', 'bar', 'laundry_service', 'price_mean']]

# %%
df1 = search[search['counts_search'] != 0]
df = df1.drop(['hotel_id'], axis = 1)

# %%
X = df.loc[:, df.columns != 'counts_search']
y = df.loc[:, df.columns == 'counts_search']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
xgb_model = xgb.XGBRegressor(objective="reg:linear", random_state=42)

xgb_model.fit(X_train, y_train)

y_pred = xgb_model.predict(X_test)

mse=metrics.mean_absolute_error(y_test, y_pred)

print(mse)
print(metrics.r2_score(y_test,y_pred))
# Out:
# [01:35:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.2.0/src/objective/regression_obj.cu:174: reg:linear is now deprecated in favor of reg:squarederror.
# [01:35:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.2.0/src/objective/regression_obj.cu:174: reg:linear is now deprecated in favor of reg:squarederror.
# 731.3794803527094
# -0.30881839652420107

# %%
li_r = LinearRegression()
li_r.fit(X_train,y_train)
y_pred = li_r.predict(X_test)
print(metrics.mean_absolute_error(y_test,y_pred))
print(metrics.r2_score(y_test,y_pred))
# Out:
# 660.0925066722499
# 0.01136580245116392

# %%
temp = search[search['counts_search'] == 0]
X_1 = temp.loc[:, temp.columns != 'counts_search']
X_2 = X_1.drop(['hotel_id'],axis = 1)
y_pred = li_r.predict(X_2)
y_1 = pd.DataFrame({'counts_search': y_pred[:,0]})
X_1 = X_1.reset_index()
temp_modeled = pd.concat([X_1, y_1], axis = 1)

# %%
rank1 = pd.concat([search[search['counts_search'] != 0], temp_modeled], axis = 0)
rank1 = rank1.drop(['index'], axis = 1)

# %%
rank2 = rank1.merge(rank[['hotel_id', 'counts_click']], on ='hotel_id')

# %%
#lo_r = LogisticRegression()
#lo_r.fit(X_train,y_train)
#print_evaluation_metrics(lo_r,LogisticRegression,X_test,y_test)

# %%
#regressor_list,regressor_name_list = get_ensemble_models()
#for regressor,regressor_name in zip(regressor_list,regressor_name_list):
    #regressor.fit(X_train,y_train)
    #print_evaluation_metrics(regressor,regressor_name,X_test,y_test)

# %% [markdown]
# # Fill Missing Value of counts_click

# %%
click = rank2[['hotel_id', 'score_mean', 'counts_search','counts_click', 'review_score', 'tours','relax_spa','currency_exchange',
 'safely_deposit_boxed', 'luggage_storage', 'restaurants', 'concierge',
 'front_desk_24_hour', 'bar', 'laundry_service', 'price_mean']]

# %%
df = click[click['counts_click'] != 0]
df = df.drop(['hotel_id'], axis = 1)

# %%
X = df.loc[:, df.columns != 'counts_click']
y = df.loc[:, df.columns == 'counts_click']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
li_r = LinearRegression()
li_r.fit(X_train,y_train)
y_pred = li_r.predict(X_test)
print(metrics.mean_absolute_error(y_test,y_pred))
print(metrics.r2_score(y_test,y_pred))
# Out:
# 25.872035374868915
# 0.005293145506928054

# %%
temp = click[click['counts_click'] == 0]
X_1 = temp.loc[:, temp.columns != 'counts_click']
X_2 = X_1.drop(['hotel_id'],axis = 1)
y_pred = li_r.predict(X_2)
y_1 = pd.DataFrame({'counts_click': y_pred[:,0]})
X_1 = X_1.reset_index()
temp_modeled = pd.concat([X_1, y_1], axis = 1)

# %%
rank2 = pd.concat([click[click['counts_click'] != 0], temp_modeled], axis = 0)
rank2 = rank2.drop(['index'], axis = 1)

# %%
rank3 = rank2.merge(rank[['hotel_id', 'counts_book']], on ='hotel_id')

# %% [markdown]
# # Fill Missing Value of counts_book

# %%
book = rank3[['hotel_id', 'score_mean', 'counts_search', 'counts_click', 'counts_book', 'review_score', 'tours','relax_spa','currency_exchange',
 'safely_deposit_boxed', 'luggage_storage', 'restaurants', 'concierge',
 'front_desk_24_hour', 'bar', 'laundry_service', 'price_mean']]

# %%
df = book[book['counts_book'] != 0]
df = df.drop(['hotel_id'], axis = 1)

# %%
X = df.loc[:, df.columns != 'counts_book']
y = df.loc[:, df.columns == 'counts_book']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
li_r = LinearRegression()
li_r.fit(X_train,y_train)
y_pred = li_r.predict(X_test)
print(metrics.mean_absolute_error(y_test,y_pred))
# Out:
# 4.0192214431893465

# %%
temp = book[book['counts_book'] == 0]
X_1 = temp.loc[:, temp.columns != 'counts_book']
X_2 = X_1.drop(['hotel_id'],axis = 1)
y_pred = li_r.predict(X_2)
y_1 = pd.DataFrame({'counts_book': y_pred[:,0]})
X_1 = X_1.reset_index()
temp_modeled = pd.concat([X_1, y_1], axis = 1)

# %%
rank3 = pd.concat([book[book['counts_book'] != 0], temp_modeled], axis = 0)
rank3 = rank3.drop(['index'], axis = 1)

# %%
rank = rank.drop(['counts_click','counts_search','counts_book'], axis = 1).merge(rank3[['hotel_id', 'counts_click','counts_search','counts_book']], on ='hotel_id')

# %%
rank.T
# Out:
#                                                                              0     \
# hotel_id                                                                    40415
# name                            Premier Residences Phu Quoc Emerald Bay Manage...
# address                                  Khem Beach An Thới, Phú Quốc, Kiên Giang
# overall_score_OTA                                                         87.7083
# overall_score                                                                  88
# score_mean                                                                87.8542
# review_score                                                                  362
# SCORE                                                                      366396
# province_id                                                                     2
# district_id                                                                   446
# latitude                                                                  10.0351
# longitude                                                                 104.028
# description                     <p style=text-align: justify;><span style=font...
# tours                                                                          -1
# night_club                                                                     -1
# relax_spa                                                                      -1
# relax_massage                                                                  -1
# relax_steam_room                                                               -1
# relax_outdoor_room                                                             -1
# relax_outdoor_pool                                                             -1
# relax_sauna                                                                    -1
# relax_pool                                                                     -1
# currency_exchange                                                              -1
# room_service_24_hour                                                           -1
# elevator                                                                       -1
# safely_deposit_boxed                                                           -1
# luggage_storage                                                                -1
# poolside_bar                                                                   -1
# airport_transfer                                                               -1
# restaurants                                                                    -1
# concierge                                                                      -1
# shops                                                                          -1
# meeting_facilities                                                             -1
# baby_sitting                                                                   -1
# facilities_for_disabled_guests                                                 -1
# private_beach                                                                  -1
# front_desk_24_hour                                                              1
# bar                                                                            -1
# laundry_service                                                                -1
# shuttle_room                                                                   -1
# price_mean                                                            2.01273e+06
# counts_click                                                                  950
# counts_search                                                                 818
# counts_book                                                                    20
#
#                                                                              1     \
# hotel_id                                                                    40412
# name                            Seashells Hotel & Spa Phú Quốc (Seashells Phu ...
# address                         Vo Thi Sau, Dương Đông, Đảo Phú Quốc, Việt Nam
# overall_score_OTA                                                              90
# overall_score                                                                  91
# score_mean                                                                   90.5
# review_score                                                               8101.9
# SCORE                                                                      285112
# province_id                                                                     2
# district_id                                                                   446
# latitude                                                                  10.2148
# longitude                                                                 103.959
# description                     Tọa lạc tại Dương Đông, Seashells Hotel & Spa ...
# tours                                                                           1
# night_club                                                                     -1
# relax_spa                                                                       1
# relax_massage                                                                   1
# relax_steam_room                                                               -1
# relax_outdoor_room                                                             -1
# relax_outdoor_pool                                                              1
# relax_sauna                                                                    -1
# relax_pool                                                                     -1
# currency_exchange                                                               1
# room_service_24_hour                                                            1
# elevator                                                                        1
# safely_deposit_boxed                                                            1
# luggage_storage                                                                 1
# poolside_bar                                                                    1
# airport_transfer                                                                1
# restaurants                                                                     1
# concierge                                                                       1
# shops                                                                          -1
# meeting_facilities                                                              1
# baby_sitting                                                                    1
# facilities_for_disabled_guests                                                  1
# private_beach                                                                   0
# front_desk_24_hour                                                              1
# bar                                                                             1
# laundry_service                                                                 1
# shuttle_room                                                                   -1
# price_mean                                                            1.53773e+06
# counts_click                                                                  408
# counts_search                                                                1691
# counts_book                                                                    22
#
#                                                                              2     \
# hotel_id                                                                    38408
# name                                                                  Aaron Hotel
# address                         Số 6 Trần Quang Khải, Thành Phố Nha Trang, Khá...
# overall_score_OTA                                                              86
# overall_score                                                                  86
# score_mean                                                                     86
# review_score                                                              216.818
# SCORE                                                                      253527
# province_id                                                                    43
# district_id                                                                   414
# latitude                                                                  12.2338
# longitude                                                                 109.197
# description                     <p>Với du khách muốn cảm nhận nhịp sống và hơi...
# tours                                                                           1
# night_club                                                                     -1
# relax_spa                                                                       1
# relax_massage                                                                  -1
# relax_steam_room                                                                0
# relax_outdoor_room                                                             -1
# relax_outdoor_pool                                                              1
# relax_sauna                                                                     0
# relax_pool                                                                     -1
# currency_exchange                                                               1
# room_service_24_hour                                                           -1
# elevator                                                                        1
# safely_deposit_boxed                                                            1
# luggage_storage                                                                 1
# poolside_bar                                                                   -1
# airport_transfer                                                                1
# restaurants                                                                     1
# concierge                                                                       1
# shops                                                                           0
# meeting_facilities                                                              1
# baby_sitting                                                                    1
# facilities_for_disabled_guests                                                 -1
# private_beach                                                                   0
# front_desk_24_hour                                                              1
# bar                                                                             1
# laundry_service                                                                 1
# shuttle_room                                                                   -1
# price_mean                                                                 486795
# counts_click                                                                  367
# counts_search                                                                4591
# counts_book                                                                    12
#
#                                                                              3     \
# hotel_id                                                                    45545
# name                                                    Green Tree Hotel Phú Quốc
# address                         Khu tổ hợp du lịch Sonasea Villas & Resort, Bã...
# overall_score_OTA                                                            94.5
# overall_score                                                                  94
# score_mean                                                                  94.25
# review_score                                                              419.083
# SCORE                                                                      250369
# province_id                                                                     2
# district_id                                                                   446
# latitude                                                                  10.1329
# longitude                                                                 103.983
# description                     <p>Khách sạn Green Tree hotel Phú Quốc nằm tro...
# tours                                                                           1
# night_club                                                                     -1
# relax_spa                                                                       0
# relax_massage                                                                   0
# relax_steam_room                                                               -1
# relax_outdoor_room                                                             -1
# relax_outdoor_pool                                                             -1
# relax_sauna                                                                    -1
# relax_pool                                                                     -1
# currency_exchange                                                               1
# room_service_24_hour                                                            1
# elevator                                                                        0
# safely_deposit_boxed                                                            1
# luggage_storage                                                                 0
# poolside_bar                                                                   -1
# airport_transfer                                                                1
# restaurants                                                                     1
# concierge                                                                       0
# shops                                                                          -1
# meeting_facilities                                                              0
# baby_sitting                                                                   -1
# facilities_for_disabled_guests                                                  0
# private_beach                                                                   0
# front_desk_24_hour                                                              1
# bar                                                                             1
# laundry_service                                                                 1
# shuttle_room                                                                   -1
# price_mean                                                                 465682
# counts_click                                                                  431
# counts_search                                                                3750
# counts_book                                                                     8
#
#                                                                              4     \
# hotel_id                                                                    45572
# name                                                           Golden Lotus Hotel
# address                         96B4 Trần Phú, Lộc Thọ, Thành Phố Nha Trang, K...
# overall_score_OTA                                                            32.5
# overall_score                                                                32.5
# score_mean                                                                   32.5
# review_score                                                                  -14
# SCORE                                                                      238066
# province_id                                                                    43
# district_id                                                                   414
# latitude                                                                   12.227
# longitude                                                                   109.2
# description                     <p>Golden Lotus Hotel nằm ở vị trí đắc địa trê...
# tours                                                                          -1
# night_club                                                                     -1
# relax_spa                                                                      -1
# relax_massage                                                                  -1
# relax_steam_room                                                               -1
# relax_outdoor_room                                                             -1
# relax_outdoor_pool                                                             -1
# relax_sauna                                                                    -1
# relax_pool                                                                     -1
# currency_exchange                                                              -1
# room_service_24_hour                                                           -1
# elevator                                                                       -1
# safely_deposit_boxed                                                           -1
# luggage_storage                                                                -1
# poolside_bar                                                                   -1
# airport_transfer                                                               -1
# restaurants                                                                    -1
# concierge                                                                      -1
# shops                                                                          -1
# meeting_facilities                                                             -1
# baby_sitting                                                                   -1
# facilities_for_disabled_guests                                                 -1
# private_beach                                                                  -1
# front_desk_24_hour                                                              1
# bar                                                                            -1
# laundry_service                                                                -1
# shuttle_room                                                                   -1
# price_mean                                                                 382602
# counts_click                                                                  777
# counts_search                                                                2618
# counts_book                                                                     6
#
#                                                                              5     \
# hotel_id                                                                    38420
# name                                                        Smile Hotel Nha Trang
# address                           45/1 Hùng Vương, Thành Phố Nha Trang, Khánh Hòa
# overall_score_OTA                                                              90
# overall_score                                                                  86
# score_mean                                                                     88
# review_score                                                                  766
# SCORE                                                                      236996
# province_id                                                                    43
# district_id                                                                   414
# latitude                                                                  12.2368
# longitude                                                                 109.195
# description                     <p>Smile Hotel Nha Trang tọa lạc tại trung tâm...
# tours                                                                           1
# night_club                                                                     -1
# relax_spa                                                                      -1
# relax_massage                                                                  -1
# relax_steam_room                                                               -1
# relax_outdoor_room                                                             -1
# relax_outdoor_pool                                                              1
# relax_sauna                                                                    -1
# relax_pool                                                                     -1
# currency_exchange                                                               1
# room_service_24_hour                                                           -1
# elevator                                                                       -1
# safely_deposit_boxed                                                            1
# luggage_storage                                                                 1
# poolside_bar                                                                    1
# airport_transfer                                                               -1
# restaurants                                                                     1
# concierge                                                                       1
# shops                                                                          -1
# meeting_facilities                                                             -1
# baby_sitting                                                                    1
# facilities_for_disabled_guests                                                 -1
# private_beach                                                                  -1
# front_desk_24_hour                                                              1
# bar                                                                             1
# laundry_service                                                                 1
# shuttle_room                                                                   -1
# price_mean                                                                 548485
# counts_click                                                                  262
# counts_search                                                                3583
# counts_book                                                                    15
#
#                                                                              6     \
# hotel_id                                                                    30436
# name                                                     Cozrum Homes Trương Định
# address                                       73 Trương Định, Quận 3, Hồ Chí Minh
# overall_score_OTA                                                              84
# overall_score                                                                  88
# score_mean                                                                     86
# review_score                                                              448.833
# SCORE                                                                      217779
# province_id                                                                    33
# district_id                                                                   481
# latitude                                                                  10.7768
# longitude                                                                  106.69
# description                     <p>Tọa lac tại Quận 3 Thành Phố Hồ Chí Minh,&n...
# tours                                                                           0
# night_club                                                                     -1
# relax_spa                                                                       0
# relax_massage                                                                   0
# relax_steam_room                                                               -1
# relax_outdoor_room                                                             -1
# relax_outdoor_pool                                                             -1
# relax_sauna                                                                    -1
# relax_pool                                                                     -1
# currency_exchange                                                               0
# room_service_24_hour                                                            0
# elevator                                                                        1
# safely_deposit_boxed                                                            0
# luggage_storage                                                                 0
# poolside_bar                                                                   -1
# airport_transfer                                                                0
# restaurants                                                                     0
# concierge                                                                       0
# shops                                                                          -1
# meeting_facilities                                                              0
# baby_sitting                                                                   -1
# facilities_for_disabled_guests                                                  1
# private_beach                                                                   0
# front_desk_24_hour                                                              1
# bar                                                                             0
# laundry_service                                                                 0
# shuttle_room                                                                   -1
# price_mean                                                                 439553
# counts_click                                                                  391
# counts_search                                                                1713
# counts_book                                                                     9
#
#                                                                              7     \
# hotel_id                                                                     2101
# name                                                              Sun River Hotel
# address                          Số 132-134-136 Bạch Đằng, Quận Hải Châu, Đà Nẵng
# overall_score_OTA                                                         78.0972
# overall_score                                                                  80
# score_mean                                                                79.0486
# review_score                                                                  695
# SCORE                                                                      213044
# province_id                                                                    50
# district_id                                                                   238
# latitude                                                                  16.0675
# longitude                                                                 108.225
# description                     <p style=text-align: justify;>Sun River Hotel ...
# tours                                                                          -1
# night_club                                                                     -1
# relax_spa                                                                      -1
# relax_massage                                                                  -1
# relax_steam_room                                                               -1
# relax_outdoor_room                                                             -1
# relax_outdoor_pool                                                             -1
# relax_sauna                                                                    -1
# relax_pool                                                                     -1
# currency_exchange                                                              -1
# room_service_24_hour                                                           -1
# elevator                                                                       -1
# safely_deposit_boxed                                                           -1
# luggage_storage                                                                -1
# poolside_bar                                                                   -1
# airport_transfer                                                               -1
# restaurants                                                                    -1
# concierge                                                                      -1
# shops                                                                          -1
# meeting_facilities                                                             -1
# baby_sitting                                                                   -1
# facilities_for_disabled_guests                                                 -1
# private_beach                                                                  -1
# front_desk_24_hour                                                              1
# bar                                                                            -1
# laundry_service                                                                -1
# shuttle_room                                                                   -1
# price_mean                                                            2.02597e+06
# counts_click                                                                  388
# counts_search                                                                4770
# counts_book                                                                     2
#
#                                                                              8     \
# hotel_id                                                                    38437
# name                                                        Ibis Styles Nha Trang
# address                             86 Hùng Vương, Thành Phố Nha Trang, Khánh Hòa
# overall_score_OTA                                                              88
# overall_score                                                                  85
# score_mean                                                                   86.5
# review_score                                                                  348
# SCORE                                                                      203098
# province_id                                                                    43
# district_id                                                                   414
# latitude                                                                  12.2378
# longitude                                                                 109.195
# description                     <p style=text-align: justify;><span style=font...
# tours                                                                          -1
# night_club                                                                     -1
# relax_spa                                                                      -1
# relax_massage                                                                  -1
# relax_steam_room                                                               -1
# relax_outdoor_room                                                             -1
# relax_outdoor_pool                                                             -1
# relax_sauna                                                                    -1
# relax_pool                                                                     -1
# currency_exchange                                                              -1
# room_service_24_hour                                                           -1
# elevator                                                                       -1
# safely_deposit_boxed                                                           -1
# luggage_storage                                                                -1
# poolside_bar                                                                   -1
# airport_transfer                                                               -1
# restaurants                                                                    -1
# concierge                                                                      -1
# shops                                                                          -1
# meeting_facilities                                                             -1
# baby_sitting                                                                   -1
# facilities_for_disabled_guests                                                 -1
# private_beach                                                                  -1
# front_desk_24_hour                                                              1
# bar                                                                            -1
# laundry_service                                                                -1
# shuttle_room                                                                   -1
# price_mean                                                                 854857
# counts_click                                                                  212
# counts_search                                                                2585
# counts_book                                                                    12
#
#                                                                              9     \
# hotel_id                                                                     1680
# name                                          Khách Sạn Senriver (Senriver Hotel)
# address                                     238 Bạch Đằng, Quận Hải Châu, Đà Nẵng
# overall_score_OTA                                                              80
# overall_score                                                                  83
# score_mean                                                                   81.5
# review_score                                                               2367.6
# SCORE                                                                      197408
# province_id                                                                    50
# district_id                                                                   238
# latitude                                                                  16.0635
# longitude                                                                 108.224
# description                     <p style=text-align: justify;><span style=font...
# tours                                                                           1
# night_club                                                                     -1
# relax_spa                                                                       1
# relax_massage                                                                   1
# relax_steam_room                                                               -1
# relax_outdoor_room                                                             -1
# relax_outdoor_pool                                                              1
# relax_sauna                                                                     1
# relax_pool                                                                     -1
# currency_exchange                                                               1
# room_service_24_hour                                                           -1
# elevator                                                                       -1
# safely_deposit_boxed                                                            1
# luggage_storage                                                                 1
# poolside_bar                                                                   -1
# airport_transfer                                                               -1
# restaurants                                                                     1
# concierge                                                                      -1
# shops                                                                          -1
# meeting_facilities                                                             -1
# baby_sitting                                                                    1
# facilities_for_disabled_guests                                                 -1
# private_beach                                                                  -1
# front_desk_24_hour                                                              1
# bar                                                                             1
# laundry_service                                                                 1
# shuttle_room                                                                   -1
# price_mean                                                                 692524
# counts_click                                                                  112
# counts_search                                                                3514
# counts_book                                                                    14
#
#                                 ...  \
# hotel_id                        ...
# name                            ...
# address                         ...
# overall_score_OTA               ...
# overall_score                   ...
# score_mean                      ...
# review_score                    ...
# SCORE                           ...
# province_id                     ...
# district_id                     ...
# latitude                        ...
# longitude                       ...
# description                     ...
# tours                           ...
# night_club                      ...
# relax_spa                       ...
# relax_massage                   ...
# relax_steam_room                ...
# relax_outdoor_room              ...
# relax_outdoor_pool              ...
# relax_sauna                     ...
# relax_pool                      ...
# currency_exchange               ...
# room_service_24_hour            ...
# elevator                        ...
# safely_deposit_boxed            ...
# luggage_storage                 ...
# poolside_bar                    ...
# airport_transfer                ...
# restaurants                     ...
# concierge                       ...
# shops                           ...
# meeting_facilities              ...
# baby_sitting                    ...
# facilities_for_disabled_guests  ...
# private_beach                   ...
# front_desk_24_hour              ...
# bar                             ...
# laundry_service                 ...
# shuttle_room                    ...
# price_mean                      ...
# counts_click                    ...
# counts_search                   ...
# counts_book                     ...
#
#                                                                              5208  \
# hotel_id                                                                    47188
# name                                                OYO 592 An Nhien Hotel & Cafe
# address                                      71 Hà Huy Tập, P.3, Lâm Đồng, Đà Lạt
# overall_score_OTA                                                              20
# overall_score                                                                  20
# score_mean                                                                     20
# review_score                                                                   -3
# SCORE                                                                       20017
# province_id                                                                    20
# district_id                                                                   NaN
# latitude                                                                   11.935
# longitude                                                                 108.441
# description                     Hãy tận dụng sự tiện lợi của dịch vụ phòng ...
# tours                                                                          -1
# night_club                                                                     -1
# relax_spa                                                                      -1
# relax_massage                                                                  -1
# relax_steam_room                                                               -1
# relax_outdoor_room                                                             -1
# relax_outdoor_pool                                                             -1
# relax_sauna                                                                    -1
# relax_pool                                                                     -1
# currency_exchange                                                              -1
# room_service_24_hour                                                           -1
# elevator                                                                       -1
# safely_deposit_boxed                                                           -1
# luggage_storage                                                                -1
# poolside_bar                                                                   -1
# airport_transfer                                                               -1
# restaurants                                                                    -1
# concierge                                                                      -1
# shops                                                                          -1
# meeting_facilities                                                             -1
# baby_sitting                                                                   -1
# facilities_for_disabled_guests                                                 -1
# private_beach                                                                  -1
# front_desk_24_hour                                                              1
# bar                                                                            -1
# laundry_service                                                                -1
# shuttle_room                                                                   -1
# price_mean                                                                 175292
# counts_click                                                              32.6172
# counts_search                                                                   2
# counts_book                                                              -5.29212
#
#                                                                              5209  \
# hotel_id                                                                    37088
# name                                                Nancy Sweet Apartment - A2205
# address                         OSC Land Residence, 110 Vo Thi Sau, Thắng Tam,...
# overall_score_OTA                                                              20
# overall_score                                                                  20
# score_mean                                                                     20
# review_score                                                                    5
# SCORE                                                                       20005
# province_id                                                                    15
# district_id                                                                   686
# latitude                                                                  10.3412
# longitude                                                                 107.089
# description                     <b>Nancy Sweet Apartment - A2205</b> tọa lạc t...
# tours                                                                           0
# night_club                                                                     -1
# relax_spa                                                                       0
# relax_massage                                                                   0
# relax_steam_room                                                               -1
# relax_outdoor_room                                                             -1
# relax_outdoor_pool                                                             -1
# relax_sauna                                                                    -1
# relax_pool                                                                     -1
# currency_exchange                                                               0
# room_service_24_hour                                                            1
# elevator                                                                        0
# safely_deposit_boxed                                                            0
# luggage_storage                                                                 0
# poolside_bar                                                                   -1
# airport_transfer                                                                0
# restaurants                                                                     0
# concierge                                                                       0
# shops                                                                          -1
# meeting_facilities                                                              0
# baby_sitting                                                                   -1
# facilities_for_disabled_guests                                                  0
# private_beach                                                                   1
# front_desk_24_hour                                                              0
# bar                                                                             1
# laundry_service                                                                 0
# shuttle_room                                                                   -1
# price_mean                                                            1.48052e+06
# counts_click                                                              45.8555
# counts_search                                                             1588.69
# counts_book                                                              -7.70441
#
#                                                                              5210  \
# hotel_id                                                                    38770
# name                                                                     Hoang Ky
# ...
# front_desk_24_hour                                                              1
# bar                                                                            -1
# laundry_service                                                                -1
# shuttle_room                                                                   -1
# price_mean                                                                 321039
# counts_click                                                              62.9277
# counts_search                                                             1697.93
# counts_book                                                              -5.03052
#
#                                                                              5214  \
# hotel_id                                                                    45959
# name                                                         Touch Da Nang Hostel
# address                         K134/26 Lê Hữu Trác, An Hải Đông, Q.Sơn Trà, Đ...
# overall_score_OTA                                                              20
# overall_score                                                                  20
# score_mean                                                                     20
# review_score                                                                   -3
# SCORE                                                                       19997
# province_id                                                                    50
# district_id                                                                   NaN
# latitude                                                                  16.0582
# longitude                                                                 108.242
# description                     Khách có thể dùng bữa tại nhà hàng của Touch D...
# tours                                                                           1
# night_club                                                                     -1
# relax_spa                                                                       0
# relax_massage                                                                   0
# relax_steam_room                                                                0
# relax_outdoor_room                                                             -1
# relax_outdoor_pool                                                              0
# relax_sauna                                                                     0
# relax_pool                                                                     -1
# currency_exchange                                                               0
# room_service_24_hour                                                            1
# elevator                                                                        1
# safely_deposit_boxed                                                            1
# luggage_storage                                                                 1
# poolside_bar                                                                   -1
# airport_transfer                                                                0
# restaurants                                                                     1
# concierge                                                                       1
# shops                                                                           0
# meeting_facilities                                                              0
# baby_sitting                                                                    0
# facilities_for_disabled_guests                                                  1
# private_beach                                                                   0
# front_desk_24_hour                                                              1
# bar                                                                             0
# laundry_service                                                                 1
# shuttle_room                                                                   -1
# price_mean                                                                 305030
# counts_click                                                              29.1363
# counts_search                                                             1699.02
# counts_book                                                              -10.9199
#
#                                                                              5215  \
# hotel_id                                                                     6185
# name                                                  Phuong Ngan Hotel Ninh Binh
# address                         Số 6, Ngõ 48 phố 5, đường Chiến Thắng, phường ...
# overall_score_OTA                                                              20
# overall_score                                                                  20
# score_mean                                                                     20
# review_score                                                                   -3
# SCORE                                                                       19997
# province_id                                                                    60
# district_id                                                                   420
# latitude                                                                  20.2602
# longitude                                                                 105.972
# description                     Được thiết kế cho cả các chuyến du lịch nghỉ n...
# tours                                                                          -1
# night_club                                                                     -1
# relax_spa                                                                      -1
# relax_massage                                                                  -1
# relax_steam_room                                                               -1
# relax_outdoor_room                                                             -1
# relax_outdoor_pool                                                             -1
# relax_sauna                                                                    -1
# relax_pool                                                                     -1
# currency_exchange                                                               1
# room_service_24_hour                                                           -1
# elevator                                                                       -1
# safely_deposit_boxed                                                           -1
# luggage_storage                                                                 1
# poolside_bar                                                                   -1
# airport_transfer                                                               -1
# restaurants                                                                    -1
# concierge                                                                      -1
# shops                                                                          -1
# meeting_facilities                                                             -1
# baby_sitting                                                                   -1
# facilities_for_disabled_guests                                                 -1
# private_beach                                                                  -1
# front_desk_24_hour                                                             -1
# bar                                                                             1
# laundry_service                                                                 1
# shuttle_room                                                                    1
# price_mean                                                                 606061
# counts_click                                                              37.4426
# counts_search                                                             1321.24
# counts_book                                                               1.07278
#
#                                                                              5216  \
# hotel_id                                                                    37034
# name                                               Nancy Thuy Tien Apartment 1009
# address                         Thuy Tien Building, 84 Tran Phu, Phường 5, Vũn...
# overall_score_OTA                                                              20
# overall_score                                                                  20
# score_mean                                                                     20
# review_score                                                                   -3
# SCORE                                                                       19997
# province_id                                                                    15
# district_id                                                                   686
# latitude                                                                  10.3735
# longitude                                                                 107.056
# description                     <b>Nancy Thuy Tien Apartment 1009</b> tọa lạc ...
# tours                                                                           0
# night_club                                                                     -1
# relax_spa                                                                       0
# relax_massage                                                                   0
# relax_steam_room                                                               -1
# relax_outdoor_room                                                             -1
# relax_outdoor_pool                                                             -1
# relax_sauna                                                                    -1
# relax_pool                                                                     -1
# currency_exchange                                                               0
# room_service_24_hour                                                            0
# elevator                                                                        0
# safely_deposit_boxed                                                            0
# luggage_storage                                                                 0
# poolside_bar                                                                   -1
# airport_transfer                                                                0
# restaurants                                                                     0
# concierge                                                                       0
# shops                                                                          -1
# meeting_facilities                                                              0
# baby_sitting                                                                   -1
# facilities_for_disabled_guests                                                  0
# private_beach                                                                   1
# front_desk_24_hour                                                              0
# bar                                                                             1
# laundry_service                                                                 0
# shuttle_room                                                                   -1
# price_mean                                                            2.32792e+06
# counts_click                                                              47.9276
# counts_search                                                              1586.4
# counts_book                                                              -7.92858
#
#                                                                              5217
# hotel_id                                                                    47608
# name                                                             Anh Đào Homestay
# address                           Lử Chô 2, Lâu Thí Ngài, Bắc Hà, Lào Cai, Bắc Hà
# overall_score_OTA                                                              10
# overall_score                                                                  10
# score_mean                                                                     10
# review_score                                                                    0
# SCORE                                                                       10000
# province_id                                                                    21
# district_id                                                                   NaN
# latitude                                                                  22.5534
# longitude                                                                 104.302
# description                     Hãy thư thả ngắm cảnh từ sân thượng/sân hiên h...
# tours                                                                           0
# night_club                                                                     -1
# relax_spa                                                                       0
# relax_massage                                                                  -1
# relax_steam_room                                                                0
# relax_outdoor_room                                                             -1
# relax_outdoor_pool                                                              0
# relax_sauna                                                                     0
# relax_pool                                                                     -1
# currency_exchange                                                               0
# room_service_24_hour                                                           -1
# elevator                                                                        0
# safely_deposit_boxed                                                            0
# luggage_storage                                                                 1
# poolside_bar                                                                   -1
# airport_transfer                                                                0
# restaurants                                                                     0
# concierge                                                                       0
# shops                                                                           0
# meeting_facilities                                                              0
# baby_sitting                                                                    0
# facilities_for_disabled_guests                                                 -1
# private_beach                                                                   0
# front_desk_24_hour                                                              0
# bar                                                                             1
# laundry_service                                                                 1
# shuttle_room                                                                   -1
# price_mean                                                                 185878
# counts_click                                                              38.1167
# counts_search                                                             1647.34
# counts_book                                                              -7.40195
#
# [44 rows x 5218 columns]

# %%
rank[rank['counts_click'] <= 0] = 0
rank[rank['counts_search'] <= 0] = 0
rank[rank['counts_book'] <= 0] = 0
