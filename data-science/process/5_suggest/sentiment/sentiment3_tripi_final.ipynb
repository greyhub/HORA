# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets,linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import pandas as pd
# load the boston dataset

# %%
df = pd.read_csv("dfWithPositiveNegative.csv")
df.T
# Out:
#                              0       \
# Unnamed: 0                        0
# index                        186061
# domain_hotel_id             4303133
# username                  Anonymous
# review_id               3.21806e+09
# score                       2.83333
# Is_Response                 neutral
# id                                0
# review           Clean, comfortable
# sentiment                         0
# length                           18
# Negative                   0.560273
# Positive                   0.439727
#
#                                                             1       \
# Unnamed: 0                                                       1
# index                                                        71684
# domain_hotel_id                                            1320362
# username                                                       Jys
# review_id                                               3.4894e+09
# score                                                          3.5
# Is_Response                                                neutral
# id                                                               1
# review           The location was great, close to many of the c...
# sentiment                                                        0
# length                                                         199
# Negative                                                  0.708453
# Positive                                                  0.291547
#
#                                                             2       \
# Unnamed: 0                                                       2
# index                                                       186570
# domain_hotel_id                                            2183217
# username                                                   Dan2how
# review_id                                              4.50081e+09
# score                                                      3.83333
# Is_Response                                                   good
# id                                                               2
# review           Walking distance to Hoi An Ancient Town. Frien...
# sentiment                                                        1
# length                                                          82
# Negative                                                  0.536111
# Positive                                                  0.463889
#
#                                                             3       \
# Unnamed: 0                                                       3
# index                                                       183514
# domain_hotel_id                                            4542179
# username                                                 Anonymous
# review_id                                              4.52216e+09
# score                                                          3.6
# Is_Response                                                   good
# id                                                               3
# review           host was nice\r\nfree bicycle rental\r\nnear t...
# sentiment                                                        0
# length                                                          74
# Negative                                                  0.605217
# Positive                                                  0.394783
#
#                                                             4       \
# Unnamed: 0                                                       4
# index                                                        36985
# domain_hotel_id                                            1778707
# username                                                      Jone
# review_id                                              2.31097e+09
# score                                                          2.5
# Is_Response                                                neutral
# id                                                               4
# review           The location was excelent. \nWe checked in ear...
# sentiment                                                        0
# length                                                         152
# Negative                                                  0.800362
# Positive                                                  0.199638
#
#                                                             5       \
# Unnamed: 0                                                       5
# index                                                       265749
# domain_hotel_id                                            2669235
# username                                                   Nicolai
# review_id                                              4.47188e+09
# score                                                      3.83333
# Is_Response                                                   good
# id                                                               5
# review           The service was excellent. They help us with e...
# sentiment                                                        1
# length                                                         115
# Negative                                                  0.197488
# Positive                                                  0.802512
#
#                                        6       \
# Unnamed: 0                                  6
# index                                   90540
# domain_hotel_id                        256409
# username                               Duncan
# review_id                         3.45208e+09
# score                                 3.33333
# Is_Response                           neutral
# id                                          6
# review           Good value, great breakfast
# sentiment                                   0
# length                                     28
# Negative                              0.58716
# Positive                              0.41284
#
#                                           7       \
# Unnamed: 0                                     7
# index                                      23808
# domain_hotel_id                          1119706
# username                                Laurence
# review_id                            4.48185e+09
# score                                          3
# Is_Response                              neutral
# id                                             7
# review           Excellent service and personnel
# sentiment                                      0
# length                                        31
# Negative                                0.552504
# Positive                                0.447496
#
#                                                          8       \
# Unnamed: 0                                                    8
# index                                                    209775
# domain_hotel_id                                         1191662
# username                                              Anonymous
# review_id                                           1.88501e+09
# score                                                         3
# Is_Response                                             neutral
# id                                                            8
# review           It was a good location and breakfast was nice.
# sentiment                                                     0
# length                                                       46
# Negative                                               0.933723
# Positive                                              0.0662772
#
#                                                             9       ...  \
# Unnamed: 0                                                       9  ...
# index                                                       273198  ...
# domain_hotel_id                                            4850239  ...
# username                                                     Sarah  ...
# review_id                                              3.90887e+09  ...
# score                                                            4  ...
# Is_Response                                              wonderful  ...
# id                                                               9  ...
# review           Everything was great, had a comfy stay! Great ...  ...
# sentiment                                                        1  ...
# length                                                         125  ...
# Negative                                                  0.604507  ...
# Positive                                                  0.395493  ...
#
#                                    248332  \
# Unnamed: 0                         248332
# index                               44573
# domain_hotel_id                   4507518
# username                        Anonymous
# review_id                     4.52194e+09
# score                                 3.2
# Is_Response                       neutral
# id                                 248332
# review           Facilities and amenities
# sentiment                               0
# length                                 24
# Negative                         0.611671
# Positive                         0.388329
#
#                                                             248333  \
# Unnamed: 0                                                  248333
# index                                                       243396
# domain_hotel_id                                            1115837
# username                                                       Amy
# review_id                                              4.48894e+09
# score                                                            4
# Is_Response                                              wonderful
# id                                                          248333
# review           Great location. Very friendly staff. Would rec...
# sentiment                                                        1
# length                                                          52
# Negative                                                  0.333461
# Positive                                                  0.666539
#
#                                                             248334  \
# Unnamed: 0                                                  248334
# index                                                       185294
# domain_hotel_id                                            2256105
# username                                                   Kristin
# review_id                                              3.02633e+09
# score                                                            4
# Is_Response                                              wonderful
# id                                                          248334
# review           Everything, perfect like all the other times w...
# sentiment                                                        1
# length                                                         223
# Negative                                                  0.219427
# Positive                                                  0.780573
#
#                                             248335  \
# Unnamed: 0                                  248335
# index                                       212208
# domain_hotel_id                            1830458
# username                                     Wendy
# review_id                              1.40038e+09
# score                                      2.16667
# Is_Response                                neutral
# id                                          248335
# review           Very nice pool and views at night
# sentiment                                        0
# length                                          33
# Negative                                  0.831834
# Positive                                  0.168166
#
#                                                             248336  \
# Unnamed: 0                                                  248336
# index                                                       279968
# domain_hotel_id                                            5647782
# username                                                    Hannah
# review_id                                              2.82864e+09
# score                                                            4
# Is_Response                                              wonderful
# id                                                          248336
# review           Room was amazing with beautiful views of the m...
# sentiment                                                        1
# length                                                         396
# Negative                                                  0.331071
# Positive                                                  0.668929
#
#                                                             248337  \
# Unnamed: 0                                                  248337
# index                                                        12348
# domain_hotel_id                                            2968256
# username                                                      Pete
# review_id                                              4.52039e+09
# score                                                          2.8
# Is_Response                                                neutral
# id                                                          248337
# review           Very clean hotel. The room I had was spotless ...
# sentiment                                                        0
# length                                                         105
# Negative                                                  0.586932
# Positive                                                  0.413068
#
#                                                             248338  \
# Unnamed: 0                                                  248338
# index                                                       149554
# domain_hotel_id                                            2735905
# username                                                 Margarida
# review_id                                              3.67726e+09
# score                                                            4
# Is_Response                                              wonderful
# id                                                          248338
# review           The family is lovely and you can join them for...
# sentiment                                                        1
# length                                                         223
# Negative                                                  0.266293
# Positive                                                  0.733707
#
#                       248339  \
# Unnamed: 0            248339
# index                 115562
# domain_hotel_id      3635919
# username               Lá»c
# review_id        2.05322e+09
# score                      3
# Is_Response          neutral
# id                    248339
# review           Good place!
# sentiment                  0
# length                    11
# Negative            0.725688
# Positive            0.274312
#
#                                                             248340  \
# Unnamed: 0                                                  248340
# index                                                       184576
# domain_hotel_id                                             822951
# username                                                     Simon
# review_id                                              4.44051e+09
# score                                                      3.33333
# Is_Response                                                neutral
# id                                                          248340
# review           Location is excellent, staff were great, very ...
# sentiment                                                        0
# length                                                          54
# Negative                                                  0.371069
# Positive                                                  0.628931
#
#                                                             248341
# Unnamed: 0                                                  248341
# index                                                        17170
# domain_hotel_id                                            2669521
# username                                                     Allan
# review_id                                               4.4825e+09
# score                                                            3
# Is_Response                                                neutral
# id                                                          248341
# review           clean and spaceous room. very friendly and eff...
# sentiment                                                        0
# length                                                          58
# Negative                                                  0.612521
# Positive                                                  0.387479
#
# [13 rows x 248342 columns]

# %%
X = df[['Negative','Positive']]
y = df['score']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.svm import SVR
from sklearn.ensemble import BaggingRegressor
from sklearn.datasets import make_regression
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
def get_ensemble_models():
    rf = RandomForestRegressor(n_estimators=51,min_samples_leaf=5,min_samples_split=3)
    bagg = BaggingRegressor(n_estimators=51,random_state=42)
    extra = ExtraTreesRegressor(n_estimators=51,random_state=42)
    ada = AdaBoostRegressor(n_estimators=51,random_state=42)
    grad = GradientBoostingRegressor(n_estimators=51,random_state=42)
    regressor_list = [rf,bagg,extra,ada,grad]
    regressor_name_list = ['Random Forests','Bagging','Extra Trees','AdaBoost','Gradient Boost']
    return regressor_list,regressor_name_list
    
def print_evaluation_metrics(trained_model,trained_model_name,X_test,y_test):
    print('--------- Model : ', trained_model_name, ' ---------------\n')
    predicted_values = trained_model.predict(X_test)
    print(metrics.mean_absolute_error(y_test,predicted_values))
    print('Mean Absolute Error (MAE):', metrics.mean_absolute_error(y_test,predicted_values))
    print('Mean Squared Error (MSE):', metrics.mean_squared_error(y_test,predicted_values))
    print('Root Mean Squared Error (RMSE):', np.sqrt(metrics.mean_squared_error(y_test,predicted_values)))
    print('R2_score:', trained_model.score(X_test,y_test))
    print("---------------------------------------\n")

# %%
import joblib

# %% [markdown]
# ### --------- Model :  Random Forests  ---------------

# %%
rf = RandomForestRegressor(n_estimators=51,min_samples_leaf=5,min_samples_split=3)
rf_name = 'Random Forests'
rf.fit(X_train,y_train)
print_evaluation_metrics(rf,rf_name,X_test,y_test)
joblib.dump(rf, "rf.model")
# Out:
# --------- Model :  Random Forests  ---------------
#
# 0.36300546072034545
# Mean Absolute Error (MAE): 0.36300546072034545
# Mean Squared Error (MSE): 0.2616997560942225
# Root Mean Squared Error (RMSE): 0.5115659841058849
# R2_score: 0.2654436501993389
# ---------------------------------------
# ['rf.model']

# %% [markdown]
# ### --------- Model :  Bagging  ---------------

# %%
bagg = BaggingRegressor(n_estimators=51,random_state=42)
bagg_name = 'Bagging'
bagg.fit(X_train,y_train)
print_evaluation_metrics(bagg,bagg_name,X_test,y_test)
joblib.dump(bagg,"bagg.model")
# Out:
# --------- Model :  Bagging  ---------------
#
# 0.3989317412102338
# Mean Absolute Error (MAE): 0.3989317412102338
# Mean Squared Error (MSE): 0.3268295075055856
# Root Mean Squared Error (RMSE): 0.5716900449593167
# R2_score: 0.08263311504954529
# ---------------------------------------
# ['bagg.model']

# %% [markdown]
# ### --------- Model :  Extra Trees  ---------------

# %%
extra = ExtraTreesRegressor(n_estimators=51,random_state=42)
extra_name = 'Extra Trees'
extra.fit(X_train,y_train)
print_evaluation_metrics(extra,extra_name,X_test,y_test)
joblib.dump(extra,'extra_trees.model')
# Out:
# --------- Model :  Extra Trees  ---------------
#
# 0.4172181536177361
# Mean Absolute Error (MAE): 0.4172181536177361
# Mean Squared Error (MSE): 0.3661417653371045
# Root Mean Squared Error (RMSE): 0.6050964925837072
# R2_score: -0.02771115521697376
# ---------------------------------------
# ['extra_trees.model']

# %% [markdown]
# ### --------- Model :  AdaBoost  ---------------

# %%
ada = AdaBoostRegressor(n_estimators=51,random_state=42)
ada_name = 'AdaBoost'
ada.fit(X_train,y_train)
print_evaluation_metrics(ada,ada_name,X_test,y_test)
joblib.dump(ada,'adaboost.model')
# Out:
# --------- Model :  AdaBoost  ---------------
#
# 0.416820954825061
# Mean Absolute Error (MAE): 0.416820954825061
# Mean Squared Error (MSE): 0.2872927499846322
# Root Mean Squared Error (RMSE): 0.5359969682606723
# R2_score: 0.1936075260348159
# ---------------------------------------
# ['adaboost.model']

# %% [markdown]
# ### --------- Model :  Gradient Boost  ---------------

# %%
grad = GradientBoostingRegressor(n_estimators=51,random_state=42)
grad_name = 'Gradient Boost'
grad.fit(X_train,y_train)
print_evaluation_metrics(grad,grad_name,X_test,y_test)
joblib.dump(grad,'gradientBoost.model')
# Out:
# --------- Model :  Gradient Boost  ---------------
#
# 0.3466651837737491
# Mean Absolute Error (MAE): 0.3466651837737491
# Mean Squared Error (MSE): 0.23803867792071498
# Root Mean Squared Error (RMSE): 0.48789207609953555
# R2_score: 0.3318571443304613
# ---------------------------------------
# ['gradientBoost.model']
