# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read data

# %%
hotel_map = pd.read_csv('cleaned-table/hotel_map.csv')
hotel_map.T
# Out:
#                                                                 0     \
# domain_hotel_id                                                10953
# hotel_id_encoded                f80bcd2b-c7ef-4fc8-aecd-86c587d6e448
# name_OTA                                        Furama Resort Danang
# address_OTA        Số 105, Đường Võ Nguyên Giáp, Phường Khuê Mỹ, ...
# star_number_OTA                                                    5
# overall_score_OTA                                                8.5
# hotel_id                                                       43835
# domain_id                                                          3
# similar_point                                               0.956682
# name                   Furama Resort Da Nang (Resort Furama Đà Nẵng)
# address               105 Võ Nguyên Giáp, Quận Ngũ Hành Sơn, Đà Nẵng
# province_id                                                       50
# district_id                                                      412
# ...

# %%
hotel_map_tmp = hotel_map[['name', 'star_number_OTA', 
                           'overall_score_OTA' ,'overall_score', 'hotel_id', 'domain_id', 'domain_hotel_id']]
hotel_map_tmp.T
# Out:
#                                                             0            1     \
# name               Furama Resort Da Nang (Resort Furama Đà Nẵng)  Danly Hotel
# star_number_OTA                                                5            5
# overall_score_OTA                                            8.5          8.3
# overall_score                                                 99           67
# hotel_id                                                   43835         9674
# domain_id                                                      3            3
# domain_hotel_id                                            10953        10960
#
#                                                              2     \
# name               Khách Sạn du Parc Hà Nội (Hôtel du Parc Hanoï)
# star_number_OTA                                                 5
# overall_score_OTA                                             8.2
# overall_score                                                  81
# ...

# %%
hotel_map_tmp.isnull().sum()
# Out:
# name                    0
# star_number_OTA         0
# overall_score_OTA       0
# overall_score        1370
# hotel_id                0
# domain_id               0
# domain_hotel_id         0
# dtype: int64

# %%
hotel_map_tmp[hotel_map_tmp['overall_score_OTA'] <= 0].count()
# Out:
# name                 1989
# star_number_OTA      1989
# overall_score_OTA    1989
# overall_score        1353
# hotel_id             1989
# domain_id            1989
# domain_hotel_id      1989
# dtype: int64

# %%
hotel_map_tmp['rank'] = hotel_map_tmp['overall_score'].rank(method='max')
hotel_map_tmp.sort_values('rank', inplace=True)
hotel_map_tmp
# Out:
# /home/luongnv/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/luongnv/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                       name  star_number_OTA  \
# 7556                           Janee Hotel                3
# 1183                     Lien My Tam Hotel                2
# ...

# %%
hotel_map_tmp[['rank']].isna().value_counts()
# Out:
# rank
# False    8077
# True     1370
# dtype: int64

# %%
# hotel_logging = pd.read_csv('table/others/hotel_logging.csv')
hotel_logging.T
# Out:
# -------------------------------------------
# NameError Traceback (most recent call last)
# <ipython-input-8-106aab95ec8f> in <module>
#       1 # hotel_logging = pd.read_csv('table/others/hotel_logging.csv')
# ----> 2 hotel_logging.T
#
# NameError: name 'hotel_logging' is not defined
